# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

img=cv2.imread('test image.jpg')
img1=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img1)

# %%
img=cv2.imread('img2.png')
img2=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img2)

# %%
height=img1.shape[1]
width=img1.shape[0]

# %%
img2[0:width,0:height]=img1

# %%
plt.imshow(img2)
