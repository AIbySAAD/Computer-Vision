# %%
import cv2
import matplotlib.pyplot as plt
book=cv2.imread('book.jpg',0)
book=cv2.cvtColor(book,cv2.COLOR_BGR2RGB)
book
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
books=cv2.imread('books.jpg',0)
books=cv2.cvtColor(books,cv2.COLOR_BGR2RGB)
books
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
import cv2
import numpy as np

# Load images
img1 = cv2.imread('book.jpg', cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread('books.jpg', cv2.IMREAD_GRAYSCALE)

# Initialize SIFT Detector
sift = cv2.SIFT_create()

# Detect keypoints and descriptors
kp1, des1 = sift.detectAndCompute(img1, None)
kp2, des2 = sift.detectAndCompute(img2, None)

# FLANN parameters
FLANN_INDEX_KDTREE = 1
index_params = dict(algorithm=FLANN_INDEX_KDTREE, trees=5)
search_params = dict(checks=50)  # or pass an empty dictionary

# FLANN matcher
flann = cv2.FlannBasedMatcher(index_params, search_params)

# Match descriptors
matches = flann.knnMatch(des1, des2, k=2)

# Apply Lowe's Ratio Test
good_matches = []
for m, n in matches:
    if m.distance < 0.7 * n.distance:
        good_matches.append(m)

# Draw matches
img_matches = cv2.drawMatches(img1, kp1, img2, kp2, good_matches, None, flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)

# Display the matches
plt.imshow(img_matches)

# %%
kp1
# Out:
# (< cv2.KeyPoint 0x7e3a198dbf60>,
#  < cv2.KeyPoint 0x7e3a198dba20>,
#  < cv2.KeyPoint 0x7e3a19a88ae0>,
#  < cv2.KeyPoint 0x7e3a19a8a6a0>,
#  < cv2.KeyPoint 0x7e3a19a880c0>,
#  < cv2.KeyPoint 0x7e3a19a8bd50>,
#  < cv2.KeyPoint 0x7e3a19a894d0>,
#  < cv2.KeyPoint 0x7e3a1b4edd70>,
#  < cv2.KeyPoint 0x7e3a1981ef10>,
#  < cv2.KeyPoint 0x7e3a1981f300>,
#  < cv2.KeyPoint 0x7e3a1981e820>,
#  < cv2.KeyPoint 0x7e3a1981fba0>,
#  < cv2.KeyPoint 0x7e3a1981e6a0>,
#  < cv2.KeyPoint 0x7e3a1981ebb0>,
#  < cv2.KeyPoint 0x7e3a1981e580>,
#  < cv2.KeyPoint 0x7e3a1981f450>,
#  < cv2.KeyPoint 0x7e3a1981f4b0>,
#  < cv2.KeyPoint 0x7e3a1981e4c0>,
#  < cv2.KeyPoint 0x7e3a1981edf0>,
#  < cv2.KeyPoint 0x7e3a1981ea30>,
#  < cv2.KeyPoint 0x7e3a1981e220>,
#  < cv2.KeyPoint 0x7e3a1981e850>,
#  < cv2.KeyPoint 0x7e3a1981e910>,
#  < cv2.KeyPoint 0x7e3a1981e460>,
#  < cv2.KeyPoint 0x7e3a1981e670>,
#  < cv2.KeyPoint 0x7e3a1981da40>,
#  < cv2.KeyPoint 0x7e3a1981efa0>,
#  < cv2.KeyPoint 0x7e3a1981f420>,
#  < cv2.KeyPoint 0x7e3a198be340>,
#  < cv2.KeyPoint 0x7e3a198bd6b0>,
#  < cv2.KeyPoint 0x7e3a198be4c0>,
#  < cv2.KeyPoint 0x7e3a198bd1a0>,
#  < cv2.KeyPoint 0x7e3a198bd0b0>,
#  < cv2.KeyPoint 0x7e3a198bd110>,
#  < cv2.KeyPoint 0x7e3a198be1c0>,
#  < cv2.KeyPoint 0x7e3a198be1f0>,
#  < cv2.KeyPoint 0x7e3a198be220>,
#  < cv2.KeyPoint 0x7e3a198be250>,
#  < cv2.KeyPoint 0x7e3a198bd200>,
#  < cv2.KeyPoint 0x7e3a198bd1d0>,
#  < cv2.KeyPoint 0x7e3a198be0a0>,
#  < cv2.KeyPoint 0x7e3a198be0d0>,
#  < cv2.KeyPoint 0x7e3a198be460>,
#  < cv2.KeyPoint 0x7e3a198be3d0>)

# %%
des1
# Out:
# array([[  0.,   4.,   3., ...,   0.,   0.,   8.],
#        [ 51.,   1.,   0., ...,   0.,   1.,   3.],
#        [ 54., 141.,   0., ...,   0.,   0.,   3.],
#        ...,
#        [  0.,   0.,  33., ...,   0.,   0.,   1.],
#        [  1.,   4.,   4., ...,   0.,   1.,   2.],
#        [  0.,   0., 182., ...,   0.,   0.,   4.]], dtype=float32)
