# %%
import numpy as np
from google.colab.patches import cv2_imshow
import cv2

img=cv2.imread('img2.png')

image_now =cv2.blur(img,(5,5))
cv2_imshow(image_now)
# Out:
# <PIL.Image.Image image mode=RGB size=600x300>

# %%
import numpy as np
from google.colab.patches import cv2_imshow
import cv2

img=cv2.imread('img2.png')

g_b_image = cv2.GaussianBlur(img,(75,75),0)  # 0 is standard deviation in the direction of x
cv2_imshow(g_b_image)
# Out:
# <PIL.Image.Image image mode=RGB size=600x300>

# %%
import numpy as np
from google.colab.patches import cv2_imshow
import cv2

img=cv2.imread('/content/620c02da6b65b59cdd65d987_Bill Maynard - Mink zoom.jpg')

a = cv2.medianBlur(img,35)
cv2_imshow(a)
# Out:
# <PIL.Image.Image image mode=RGB size=1402x1196>
